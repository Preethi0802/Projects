# %% [markdown]
# <a href="https://colab.research.google.com/github/Preethi0802/Projects/blob/main/cleaning_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train =pd.read_csv("/content/train.tsv",sep="\t")

# %%
train.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %%
train.tail()
# Out:
#         train_id                                     name  item_condition_id  \
# 516673    516673            Black off the shoulder blouse                  2
# 516674    516674   MAC Pro Longwear Nourishing Foundation                  1
# 516675    516675     Free People Grey/Black Sweater Small                  3
# 516676    516676  Cathedral The Game of Medival City Game                  2
# 516677    516677                       Pink slipper boots                  2
#
#                       category_name   brand_name  price  shipping  \
# 516673  Women/Tops & Blouses/Blouse          NaN   11.0         0
# 516674           Beauty/Makeup/Face          MAC   34.0         0
# 516675    Women/Sweaters/Scoop Neck  Free People   15.0         0
# 516676              Kids/Toys/Games          NaN   20.0         1
# 516677         Women/Shoes/Slippers         PINK   25.0         1
#
#                                          item_description
# ...

# %%
train.tail()
# Out:
#         train_id                                     name  item_condition_id  \
# 516673    516673            Black off the shoulder blouse                  2
# 516674    516674   MAC Pro Longwear Nourishing Foundation                  1
# 516675    516675     Free People Grey/Black Sweater Small                  3
# 516676    516676  Cathedral The Game of Medival City Game                  2
# 516677    516677                       Pink slipper boots                  2
#
#                       category_name   brand_name  price  shipping  \
# 516673  Women/Tops & Blouses/Blouse          NaN   11.0         0
# 516674           Beauty/Makeup/Face          MAC   34.0         0
# 516675    Women/Sweaters/Scoop Neck  Free People   15.0         0
# 516676              Kids/Toys/Games          NaN   20.0         1
# 516677         Women/Shoes/Slippers         PINK   25.0         1
#
#                                          item_description
# ...

# %%
train.head(10)
# Out:
#    train_id                                    name  item_condition_id  \
# 0         0     MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1        Razer BlackWidow Chroma Keyboard                  3
# 2         2                          AVA-VIV Blouse                  1
# 3         3                   Leather Horse Statues                  1
# 4         4                    24K GOLD plated rose                  1
# 5         5        Bundled items requested for Ruie                  3
# 6         6      Acacia pacific tides santorini top                  3
# 7         7    Girls cheer and tumbling bundle of 7                  3
# 8         8                   Girls Nike Pro shorts                  3
# 9         9  Porcelain clown doll checker pants VTG                  3
#
#                                        category_name       brand_name  price  \
# 0                                  Men/Tops/T-shirts              NaN   10.0
# ...

# %%
train.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %%
train.shape
# Out:
# (516678, 8)

# %%
train['price']
# Out:
# 0         10.0
# 1         52.0
# 2         10.0
# 3         35.0
# 4         44.0
#           ...
# 516673    11.0
# 516674    34.0
# 516675    15.0
# 516676    20.0
# 516677    25.0
# Name: price, Length: 516678, dtype: float64

# %%
train['price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50,figsize=(10,5),range=[0,500])
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50,figsize=(10,5),range=[0,500],edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['price'].plot.hist(bins=50,figsize=(10,5),range=[1700,2010],edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>

# %%
p1700=train[train['price']>1700]
p1700
# Out:
#         train_id                                   name  item_condition_id  \
# 145696    145696       Louis Vuitton Monogram Metis Bag                  2
# 180749    180749                     NEW apple products                  1
# 182847    182847  Auth. chanel boy maxi lambskin France                  3
# 194639    194639                               iPad Pro                  1
# 244054    244054                                 LV Bag                  2
# 415027    415027   Chanel Classic Jumbo Single flap bag                  3
# 449729    449729     AUTH Louis Vuitton Palm Springs MM                  2
# 506623    506623   Louis Vuitton Ikat Rose Neverfull GM                  3
#
#                                             category_name     brand_name  \
# 145696                Women/Women's Handbags/Shoulder Bag  Louis Vuitton
# 180749  Electronics/Cell Phones & Accessories/Cell Pho...          Apple
# ...

# %%
p1700.shape
# Out:
# (8, 8)

# %%
p1700=train[train['price']>=1700]
p1700
# Out:
#         train_id                                   name  item_condition_id  \
# 145696    145696       Louis Vuitton Monogram Metis Bag                  2
# 180749    180749                     NEW apple products                  1
# 182847    182847  Auth. chanel boy maxi lambskin France                  3
# 194639    194639                               iPad Pro                  1
# 244054    244054                                 LV Bag                  2
# 379231    379231           Authentic saint Laurent bag.                  2
# 415027    415027   Chanel Classic Jumbo Single flap bag                  3
# 449729    449729     AUTH Louis Vuitton Palm Springs MM                  2
# 506623    506623   Louis Vuitton Ikat Rose Neverfull GM                  3
#
#                                             category_name     brand_name  \
# 145696                Women/Women's Handbags/Shoulder Bag  Louis Vuitton
# ...

# %%
p1700.shape
# Out:
# (9, 8)

# %%
p1850=train[(train['price']>=1850)&(train['price']<1950)]
p1850
# Out:
#         train_id                                   name  item_condition_id  \
# 180749    180749                     NEW apple products                  1
# 182847    182847  Auth. chanel boy maxi lambskin France                  3
# 194639    194639                               iPad Pro                  1
#
#                                             category_name brand_name   price  \
# 180749  Electronics/Cell Phones & Accessories/Cell Pho...      Apple  1909.0
# 182847                Women/Women's Handbags/Shoulder Bag     Chanel  1850.0
# 194639  Electronics/Computers & Tablets/iPad/Tablet/eB...      Apple  1900.0
#
#         shipping                                   item_description
# 180749         0  bundle includes: ipad pro keyboard, iphone 6S ...
# 182847         1  Elegant authentic chanel boy bag made in Franc...
# 194639         1  Great condition iPad Pro, biggest size with lo...

# %%
p1850.shape
# Out:
# (3, 8)

# %%
p100=train[train['price']<=100]
p100.shape
# Out:
# (502083, 8)

# %%
train.shape
# Out:
# (516678, 8)

# %%
p100.shape
# Out:
# (502083, 8)

# %%
p100.shape[0]
# Out:
# 502083

# %%
p100_per=(p100.shape[0])/(train.shape[0])*100
p100_per
# Out:
# 97.17522325316736

# %%
train['price'].max()
# Out:
# 2000.0

# %%
train['price'].min()
# Out:
# 0.0

# %% [markdown]
# train['price'].mean()

# %%
train['price'].mean()
# Out:
# 26.7037381115511

# %%
train['price'].median()
# Out:
# 17.0

# %%
train.quantile([0.25,0.5,0.75])
# Out:
# <ipython-input-31-0a1b9531bd9b>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.quantile([0.25,0.5,0.75])
#        train_id  item_condition_id  price  shipping
# 0.25  129169.25                1.0   10.0       0.0
# 0.50  258338.50                2.0   17.0       0.0
# 0.75  387507.75                3.0   29.0       1.0

# %%
train.describe()
# Out:
#            train_id  item_condition_id          price       shipping
# count  516678.00000      516678.000000  516678.000000  516678.000000
# mean   258338.50000           1.907314      26.703738       0.446292
# std    149152.23553           0.902577      38.568197       0.497108
# min         0.00000           1.000000       0.000000       0.000000
# 25%    129169.25000           1.000000      10.000000       0.000000
# 50%    258338.50000           2.000000      17.000000       0.000000
# 75%    387507.75000           3.000000      29.000000       1.000000
# max    516677.00000           5.000000    2000.000000       1.000000

# %%
train['item_condition_id'].unique()
# Out:
# array([3, 1, 2, 4, 5])

# %%
len(train['item_condition_id'].unique())
# Out:
# 5

# %%
len(train['train_id'].unique())
# Out:
# 516678

# %%
len(train['category_name'].unique())
# Out:
# 1184

# %%
(train['category_name'].unique())
# Out:
# array(['Men/Tops/T-shirts',
#        'Electronics/Computers & Tablets/Components & Parts',
#        'Women/Tops & Blouses/Blouse', ..., 'Handmade/Patterns/Handmade',
#        'Handmade/Dolls and Miniatures/Primitive',
#        'Kids/Potty Training/Other'], dtype=object)

# %%
len((train['name'].unique()))
# Out:
# 454614

# %%
((train['name'].unique()))
# Out:
# array(['MLB Cincinnati Reds T Shirt Size XL',
#        'Razer BlackWidow Chroma Keyboard', 'AVA-VIV Blouse', ...,
#        'Free People Grey/Black Sweater Small',
#        'Cathedral The Game of Medival City Game', 'Pink slipper boots'],
#       dtype=object)

# %%
len((train['brand_name'].unique()))
# Out:
# 3615

# %%
((train['brand_name'].unique()))
# Out:
# array([nan, 'Razer', 'Target', ..., 'Bogner', 'Fujifilm', 'Joyce Chen'],
#       dtype=object)

# %%
len((train['item_description'].unique()))
# Out:
# 456856

# %%
((train['item_description'].unique()))
# Out:
# array(['No description yet',
#        'This keyboard is in great condition and works like it came out of the box. All of the ports are tested and work perfectly. The lights are customizable via the Razer Synapse app on your PC.',
#        'Adorable top with a hint of lace and a key hole in the back! The pale pink is a 1X, and I also have a 3X available in white!',
#        ...,
#        'Size small Free People sweater. Grey/Black with 2 pockets. Has some fuzziness but still really cute! Bundle and save on other cute items listed from Buckle, American Eagle, Nordstrom, etc..',
#        '100% complete and in like new condition absolutely beautiful handcrafted wooden pieces. An overall great quality game. Enjoy :)',
#        'Very lightly worn Small black scuff mark on left boot heel, shown in third pictu'],
#       dtype=object)

# %%
len((train['shipping'].unique()))
# Out:
# 2

# %%
((train['shipping'].unique()))
# Out:
# array([1, 0])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516678 entries, 0 to 516677
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   train_id           516678 non-null  int64
#  1   name               516678 non-null  object
#  2   item_condition_id  516678 non-null  int64
#  3   category_name      514465 non-null  object
#  4   brand_name         296267 non-null  object
#  5   price              516678 non-null  float64
#  6   shipping           516678 non-null  int64
#  7   item_description   516677 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 31.5+ MB

# %%
miss_value=train.isnull()
miss_value
# Out:
#         train_id   name  item_condition_id  category_name  brand_name  price  \
# 0          False  False              False          False        True  False
# 1          False  False              False          False       False  False
# 2          False  False              False          False       False  False
# 3          False  False              False          False        True  False
# 4          False  False              False          False        True  False
# ...          ...    ...                ...            ...         ...    ...
# 516673     False  False              False          False        True  False
# 516674     False  False              False          False       False  False
# 516675     False  False              False          False       False  False
# 516676     False  False              False          False        True  False
# 516677     False  False              False          False       False  False
#
#         shipping  item_description
# ...

# %%
miss_value_some=train.isnull().sum()
miss_value_some
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          2213
# brand_name           220411
# price                     0
# shipping                  0
# item_description          1
# dtype: int64

# %%
split_category=train['category_name'].str.split("/")
split_category
# Out:
# 0                                     [Men, Tops, T-shirts]
# 1         [Electronics, Computers & Tablets, Components ...
# 2                           [Women, Tops & Blouses, Blouse]
# 3                    [Home, Home Décor, Home Décor Accents]
# 4                               [Women, Jewelry, Necklaces]
#                                 ...
# 516673                      [Women, Tops & Blouses, Blouse]
# 516674                               [Beauty, Makeup, Face]
# 516675                        [Women, Sweaters, Scoop Neck]
# 516676                                  [Kids, Toys, Games]
# 516677                             [Women, Shoes, Slippers]
# Name: category_name, Length: 516678, dtype: object

# %%
split_category_mod=train['category_name'].str.split("/",expand=True)
split_category_mod
# Out:
#                   0                    1                   2     3     4
# 0               Men                 Tops            T-shirts  None  None
# 1       Electronics  Computers & Tablets  Components & Parts  None  None
# 2             Women       Tops & Blouses              Blouse  None  None
# 3              Home           Home Décor  Home Décor Accents  None  None
# 4             Women              Jewelry           Necklaces  None  None
# ...             ...                  ...                 ...   ...   ...
# 516673        Women       Tops & Blouses              Blouse  None  None
# 516674       Beauty               Makeup                Face  None  None
# 516675        Women             Sweaters          Scoop Neck  None  None
# 516676         Kids                 Toys               Games  None  None
# 516677        Women                Shoes            Slippers  None  None
#
# [516678 rows x 5 columns]

# %%
split_category_mod.columns=['main_cat','sub_cat1','sub_cat2','sub_cat3','sub_cat4']
split_category_mod
# Out:
#            main_cat             sub_cat1            sub_cat2 sub_cat3 sub_cat4
# 0               Men                 Tops            T-shirts     None     None
# 1       Electronics  Computers & Tablets  Components & Parts     None     None
# 2             Women       Tops & Blouses              Blouse     None     None
# 3              Home           Home Décor  Home Décor Accents     None     None
# 4             Women              Jewelry           Necklaces     None     None
# ...             ...                  ...                 ...      ...      ...
# 516673        Women       Tops & Blouses              Blouse     None     None
# 516674       Beauty               Makeup                Face     None     None
# 516675        Women             Sweaters          Scoop Neck     None     None
# 516676         Kids                 Toys               Games     None     None
# 516677        Women                Shoes            Slippers     None     None
#
# ...

# %%
split_category_mod['main_cat'].unique()
# Out:
# array(['Men', 'Electronics', 'Women', 'Home', 'Sports & Outdoors',
#        'Vintage & Collectibles', 'Beauty', 'Other', 'Kids', nan,
#        'Handmade'], dtype=object)

# %%
len(split_category_mod['main_cat'].unique())
# Out:
# 11

# %%
split_category_mod['main_cat'].value_counts()
# Out:
# Women                     231579
# Beauty                     72585
# Kids                       59566
# Electronics                42734
# Men                        32677
# Home                       23822
# Vintage & Collectibles     16263
# Other                      15845
# Handmade                   10683
# Sports & Outdoors           8711
# Name: main_cat, dtype: int64

# %%
len(split_category_mod['main_cat'].value_counts())
# Out:
# 10

# %%
split_category_mod['main_cat'].value_counts().plot(kind='bar',color=['green','orange','red','yellow','blue','magenta','purple'])
# Out:
# <Axes: >

# %%
split_category_mod.columns
# Out:
# Index(['main_cat', 'sub_cat1', 'sub_cat2', 'sub_cat3', 'sub_cat4'], dtype='object')

# %%
split_category_mod['sub_cat1'].value_counts()
# Out:
# Athletic Apparel        46461
# Makeup                  43547
# Tops & Blouses          37260
# Shoes                   35085
# Jewelry                 21609
#                         ...
# Ceramics and Pottery       20
# Candles                    18
# Books and Zines            16
# Dolls and Miniatures       15
# Quilts                     11
# Name: sub_cat1, Length: 113, dtype: int64

# %%
split_category_mod['sub_cat1'].unique()
# Out:
# array(['Tops', 'Computers & Tablets', 'Tops & Blouses', 'Home Décor',
#        'Jewelry', 'Other', 'Swimwear', 'Apparel', 'Collectibles',
#        'Makeup', 'Fragrance', 'Dresses', 'Office supplies', 'Shoes',
#        'Gear', 'Athletic Apparel', 'Cell Phones & Accessories', 'Jeans',
#        'Underwear', 'Skin Care', 'Toys', "Women's Handbags",
#        'Video Games & Consoles', 'Coats & Jackets', 'Pants', 'Girls (4+)',
#        'Antique', 'Kitchen & Dining', 'Sweaters', 'Boys 0-24 Mos',
#        'Girls 0-24 Mos', 'Maternity', 'Bedding', 'Exercise',
#        'Trading Cards', 'Boys (4+)', 'Storage & Organization', 'Fan Shop',
#        'Girls 2T-5T', "Men's Accessories", 'Boys 2T-5T',
#        "Women's Accessories", 'Daily & Travel items', nan, 'Skirts',
#        'Hair Care', 'Pet Supplies', 'Book', 'Tools & Accessories',
#        'Team Sports', 'Home Appliances', 'Accessories', 'Bags and Purses',
#        'Sweats & Hoodies', 'Shorts', 'TV, Audio & Surveillance',
# ...

# %%
len(split_category_mod['sub_cat1'].unique())
# Out:
# 114

# %%
z=split_category_mod['sub_cat1'].value_counts()[0:10]

# %%
zbottom=split_category_mod['sub_cat1'].value_counts()[-10:-1]
zbottom
# Out:
# Knitting                 45
# Geekery                  44
# Woodworking              38
# Suits                    22
# Blazers & Sport Coats    20
# Ceramics and Pottery     20
# Candles                  18
# Books and Zines          16
# Dolls and Miniatures     15
# Name: sub_cat1, dtype: int64

# %%
zbottom.plot(kind="bar",color=["green","orange","red","yellow","blue","purple","magenta","indigo","lightpink","brown"])
# Out:
# <Axes: >

# %%
z
# Out:
# Athletic Apparel             46461
# Makeup                       43547
# Tops & Blouses               37260
# Shoes                        35085
# Jewelry                      21609
# Toys                         20298
# Cell Phones & Accessories    18554
# Women's Handbags             16056
# Dresses                      15871
# Women's Accessories          14774
# Name: sub_cat1, dtype: int64

# %%
z.plot(kind="bar",color=["green","orange","red","yellow","blue","purple","magenta","indigo","lightpink","brown"])
# Out:
# <Axes: >

# %%
z.plot(kind="barh",color=["green","orange","red","yellow","blue","purple","magenta","indigo","lightpink","brown"], title=" Sub Category name details")
# Out:
# <Axes: title={'center': ' Sub Category name details'}>

# %%
train["item_condition_id"].value_counts()
# Out:
# 1    223027
# 3    150455
# 2    131271
# 4     11092
# 5       833
# Name: item_condition_id, dtype: int64

# %%
train.shape
# Out:
# (516678, 8)

# %%
train["item_condition_id"].value_counts(normalize=True) * 100
# Out:
# 1    43.165569
# 3    29.119684
# 2    25.406733
# 4     2.146792
# 5     0.161222
# Name: item_condition_id, dtype: float64

# %%
train["item_condition_id"].value_counts().keys()
# Out:
# Int64Index([1, 3, 2, 4, 5], dtype='int64')

# %%
sns.barplot(x=train["item_condition_id"].value_counts().keys(), y=train["item_condition_id"].value_counts())
# Out:
# <Axes: xlabel='None', ylabel='item_condition_id'>

# %%
sns.barplot(x=train["item_condition_id"].value_counts().keys(), y=train["item_condition_id"].value_counts(), palette=["red","blue","green","pink"])
plt.xlabel("Item Condition Id")
plt.ylabel("Item Condition Count")
plt.title("Item Condition Details")
# Out:
# <ipython-input-72-d3332a3889e4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=train["item_condition_id"].value_counts().keys(), y=train["item_condition_id"].value_counts(), palette=["red","blue","green","pink"])
# <ipython-input-72-d3332a3889e4>:1: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=train["item_condition_id"].value_counts().keys(), y=train["item_condition_id"].value_counts(), palette=["red","blue","green","pink"])
# Text(0.5, 1.0, 'Item Condition Details')

# %%
p100=train[train["price"]<=100]
fig,ax=plt.subplots(figsize=(20,8))
sns.boxplot(x="item_condition_id",y="price",data=p100)
# Out:
# <Axes: xlabel='item_condition_id', ylabel='price'>

# %%
train.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %%
price1=train[train["price"]>=0]
fig,ax=plt.subplots(figsize=(20,8))
sns.boxplot(x="item_condition_id",y="price", data=price1 )
# Out:
# <Axes: xlabel='item_condition_id', ylabel='price'>

# %%
price1=train[train["price"]<=50]
fig,ax=plt.subplots(figsize=(20,8))
sns.boxplot(x="item_condition_id",y="price", data=price1 )
# Out:
# <Axes: xlabel='item_condition_id', ylabel='price'>

# %%
itemcondition_groupby=train.groupby("item_condition_id").count()
itemcondition_groupby
# Out:
#                    train_id    name  category_name  brand_name   price  \
# item_condition_id
# 1                    223027  223027         222266      106229  223027
# 2                    131271  131271         130511       82803  131271
# 3                    150455  150455         149821       98997  150455
# 4                     11092   11092          11039        7643   11092
# 5                       833     833            828         595     833
#
#                    shipping  item_description
# item_condition_id
# 1                    223027            223027
# 2                    131271            131271
# 3                    150455            150455
# 4                     11092             11091
# 5                       833               833

# %%
itemcondition_groupby=train.groupby("item_condition_id")
itemcondition_price=pd.DataFrame(itemcondition_groupby["price"])
itemcondition_price
# Out:
#    0                                                  1
# 0  1  2         10.0
# 3         35.0
# 4         44.0
# 1...
# 1  2  10         8.0
# 12        16.0
# 19        27.0
# 2...
# 2  3  0         10.0
# 1         52.0
# 5         59.0
# 6...
# 3  4  37         6.0
# 124       17.0
# 141        9.0
# 1...
# 4  5  258       14.0
# 653       36.0
# 1027      20.0
# 2...

# %%
itemcondition_groupby=train.groupby("item_condition_id")
itemcondition_price=pd.DataFrame(itemcondition_groupby["price"].describe())
itemcondition_price
# Out:
#                       count       mean        std  min   25%   50%   75%  \
# item_condition_id
# 1                  223027.0  26.489226  35.371363  0.0  10.0  18.0  30.0
# 2                  131271.0  27.480495  41.454140  0.0  11.0  17.0  29.0
# 3                  150455.0  26.508022  40.646060  0.0  11.0  16.0  28.0
# 4                   11092.0  24.042012  35.275244  0.0  10.0  15.0  26.0
# 5                     833.0  32.522209  40.667653  3.0  11.0  19.0  36.0
#
#                       max
# item_condition_id
# 1                  1909.0
# 2                  1815.0
# 3                  2000.0
# 4                  1106.0
# 5                   360.0

# %% [markdown]
# # **Brand Names**

# %%
train["brand_name"]
# Out:
# 0                 NaN
# 1               Razer
# 2              Target
# 3                 NaN
# 4                 NaN
#              ...
# 516673            NaN
# 516674            MAC
# 516675    Free People
# 516676            NaN
# 516677           PINK
# Name: brand_name, Length: 516678, dtype: object

# %%
train["brand_name"].value_counts()
# Out:
# PINK                                 18867
# Nike                                 18590
# Victoria's Secret                    16859
# LuLaRoe                              10735
# Apple                                 6003
#                                      ...
# Crosley Radio                            1
# Happy Chic Baby by Jonathan Adler        1
# Gabriel                                  1
# Campia Moda                              1
# Joyce Chen                               1
# Name: brand_name, Length: 3614, dtype: int64

# %%
train["brand_name"].nunique()
# Out:
# 4809

# %%
x=train["brand_name"].value_counts()[0:10]

# %%
sns.barplot(x=x.keys,y=x)
# Out:
# <Axes: ylabel='brand_name'>

# %%
train.isnull().sum()
# Out:
# train_id                  0
# name                      0
# item_condition_id         0
# category_name          6327
# brand_name           632682
# price                     0
# shipping                  0
# item_description          4
# dtype: int64

# %%
train['brand_name']=train['brand_name'].fillna('brand unavailable')

# %%
train['brand_name'].value_counts()
# Out:
# brand unavailable       632682
# PINK                     54088
# Nike                     54043
# Victoria's Secret        48036
# LuLaRoe                  31024
#                          ...
# The Learning Journey         1
# Pampers Baby Fresh           1
# Huggies One & Done           1
# Classic Media                1
# Kids Only                    1
# Name: brand_name, Length: 4810, dtype: int64

# %%
brand=train['brand_name'].value_counts()[0:10]
brand
# Out:
# brand unavailable    632682
# PINK                  54088
# Nike                  54043
# Victoria's Secret     48036
# LuLaRoe               31024
# Apple                 17322
# FOREVER 21            15186
# Nintendo              15007
# Lululemon             14558
# Michael Kors          13928
# Name: brand_name, dtype: int64

# %%
train['brand_name_available']=np.where(train['brand_name']=='brand unavailable','No','Yes')

# %%
train['brand_name_available'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
price1=train[train["price"]<=50]
fig,ax=plt.subplots(figsize=(20,8))
sns.boxplot(x="brand_name_available",y="price", data=price1 )
# Out:
# <Axes: xlabel='brand_name_available', ylabel='price'>

# %%
brand_name_analysis=train.groupby('brand_name_available')
brand_name_describe=pd.DataFrame(brand_name_analysis['price'].describe())
brand_name_describe
# Out:
#                          count       mean        std  min   25%   50%   75%  \
# brand_name_available
# No                    632682.0  21.133453  27.361260  0.0   9.0  14.0  24.0
# Yes                   849853.0  30.909520  44.712236  0.0  12.0  20.0  34.0
#
#                          max
# brand_name_available
# No                    2000.0
# Yes                   2009.0

# %%
brand_name_analysis=train.groupby('brand_name_available')
brand_name_describe=pd.DataFrame(brand_name_analysis['price'].count())
brand_name_describe
# Out:
#                        price
# brand_name_available
# No                    632682
# Yes                   849853

# %%
brand_name_analysis=train.groupby('brand_name_available')
brand_name_describe=pd.DataFrame(brand_name_analysis['price'].mean())
brand_name_describe
# Out:
#                           price
# brand_name_available
# No                    21.133453
# Yes                   30.909520
